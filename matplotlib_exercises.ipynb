# %% [markdown]
# ### Exercises
#
# Do your work for this exercise in a jupyter notebook named matplotlib_exercises.

# %%
#import pyplot module as alias plt
import matplotlib.pyplot as plt  

#import other libraries 
import numpy as np
import math
from random import randint
import random
import pandas as pd

# Changes the default settings for high resolution
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# 1. Use matplotlib to plot the following equation:
# * y = x^2 − x+2
#
# You'll need to write the code that generates the x and y points.
#
# Add an anotation for the point 0, 0, the origin.

# %%
#x = (-10, -5, 0, 5, 10)
x = range(-100, 100)
y = [(x ** 2) - (x + 2) for x in x]
# x, y

# %%
plt.plot(x,y)
plt.annotate('<----------- Rock Bottom!', xy = (0, 0),xytext=(0, 0), arrowprops = dict(facecolor = 'green')  )

# saves the figure as picture
plt.savefig('fig-1.png')

plt.show()

# %% [markdown]
# 2. Create and label 4 separate charts for the following equations (choose a range for x that makes sense):
#
# * y = √x
#
# * y = x^3
#
# * y = 2^x
#
# * y = 1/(x+1)
#
# You can use functions from the math module to help implement some of the equations above.

# %%
x = (-10, -5, 0, 5, 10)
#x = range(0, 100)
y1 = [(np.sqrt(np.absolute(x))) for x in x]
y2 = [(x ** 3) for x in x]
y3 = [(np.power(2, np.absolute(x))) for x in x]
y4 = [(1 / (x + 1)) for x in x]

#print(x, y1)
#print(x, y2)
#print(x, y3)
#print(x, y4)

# %%
# plot each mathematical function in a separate figure

plt.figure(figsize = (4,4))

plt.subplot(111)
plt.plot(x, y1,color = 'r', ls = '--')
plt.title('y = √x')

plt.show()

# %%
# plot each mathematical function in a separate figure

plt.figure(figsize = (4,4))

plt.subplot(111)
plt.plot(x, y2,color = 'r', ls = '--', marker = '^')
plt.title('y = x^3')

plt.show()

# %%
# plot each mathematical function in a separate figure

plt.figure(figsize = (4,4))

plt.subplot(111)
plt.plot(x, y3,color = 'g', ls = '--', marker = 'o')
plt.title('y = 2^x')

plt.show()

# %%
# plot each mathematical function in a separate figure

plt.figure(figsize = (4,4))

plt.subplot(111)
plt.plot(x, y4,color = 'm', ls = '--', marker = 'v')
plt.title('y = 1/(x+1)')

plt.show()

# %% [markdown]
# 3. Combine the figures you created in the last step into one large figure with 4 subplots.

# %%
# plot different mathematical functions vs x in a single figure

plt.figure(figsize = (8,8))
plt.suptitle('Math is Hard')

plt.subplot(221)
plt.plot(x, y1,color = 'r', ls = '--')
plt.title('y = √x')

plt.subplot(222)
plt.plot(x, y2,color = 'r', ls = '--', marker = '^')
plt.title('y = x^3')

plt.subplot(223)
plt.plot(x, y3,color = 'g', ls = '--', marker = 'o')
plt.title('y = 2^x')

plt.subplot(224)
plt.plot(x, y4,color = 'm', ls = '--', marker = 'v')
plt.title('y = 1/(x+1)')

plt.tight_layout()

plt.show()

# %% [markdown]
# 4. Combine the figures you created in the last step into one figure where each of the 4 equations has a different color for the points. Be sure to include a legend and an appropriate title for the figure.

# %%
# plot different mathematical functions vs x in a single figure
plt.figure(figsize = (8,8))
plt.suptitle('Math is Hard')

# add label
plt.legend()

# subplots
plt.subplot(221)
plt.plot(x, y1,color = 'blue', ls = '--', marker = '*', markerfacecolor='blue', markersize=12)
plt.title('y = √x')

plt.subplot(222)
plt.plot(x, y2,color = 'black', ls = '--', marker = '^', markerfacecolor='black', markersize=12)
plt.title('y = x^3')

plt.subplot(223)
plt.plot(x, y3,color = 'green', ls = '--', marker = 'o', markerfacecolor='green', markersize=12)
plt.title('y = 2^x')

plt.subplot(224)
plt.plot(x, y4,color = 'm', ls = '--', marker = 'v', markerfacecolor='yellow', markersize=12)
plt.title('y = 1/(x+1)')

plt.tight_layout()

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
